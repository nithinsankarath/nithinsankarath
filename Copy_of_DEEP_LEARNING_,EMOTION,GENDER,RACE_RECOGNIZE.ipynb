# %% [markdown]
# <a href="https://colab.research.google.com/github/nithinsankarath/nithinsankarath/blob/main/Copy_of_DEEP_LEARNING_%2CEMOTION%2CGENDER%2CRACE_RECOGNIZE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
img = cv2.imread("/content/obama crying.jpg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
# !pip install deepface

# %%
from deepface import DeepFace
pred = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 24-09-20 09:49:28 - facial_expression_model_weights.h5 will be downloaded...
#   0%|          | 0.00/5.98M [00:00<?, ?B/s]
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 46.0MB/s]
# Action: age:  25%|██▌       | 1/4 [00:01<00:05,  1.74s/it]    Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 24-09-20 09:49:34 - age_model_weights.h5 will be downloaded...
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   2%|▏         | 12.1M/539M [00:00<00:04, 119MB/s]
#   6%|▋         | 34.1M/539M [00:00<00:02, 179MB/s]
#  10%|▉         | 52.4M/539M [00:00<00:02, 174MB/s]
#  13%|█▎        | 70.3M/539M [00:00<00:02, 159MB/s]
# ...

# %%
type(pred)
pred
# Out:
# [{'emotion': {'angry': 0.0014784683998122136,
#    'disgust': 7.302316196870901e-11,
#    'fear': 12.955635068156425,
#    'happy': 1.8853632280043303e-08,
#    'sad': 87.01922816152741,
#    'surprise': 3.906420309145834e-07,
#    'neutral': 0.0236599152691053},
#   'dominant_emotion': 'sad',
#   'region': {'x': 72,
#    'y': 0,
#    'w': 801,
#    'h': 801,
#    'left_eye': (636, 240),
#    'right_eye': (309, 216)},
#   'face_confidence': 0.91,
#   'age': 43,
#   'gender': {'Woman': 0.03430261858738959, 'Man': 99.96570348739624},
#   'dominant_gender': 'Man',
#   'race': {'asian': 5.182216316461563,
#    'indian': 19.89852637052536,
#    'black': 4.318941757082939,
#    'white': 17.483249306678772,
#    'middle eastern': 7.304055988788605,
#    'latino hispanic': 45.81301212310791},
#   'dominant_race': 'latino hispanic'}]

# %%
prediction=pred[0]
prediction["dominant_emotion"]
# Out:
# 'sad'

# %%
img = cv2.imread("/content/smiling girl 1.jpg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
from deepface import DeepFace
pred = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.09it/s]

# %%
pred
# Out:
# [{'emotion': {'angry': 4.445537341024597e-09,
#    'disgust': 4.681922669005677e-15,
#    'fear': 1.3023234400610928e-09,
#    'happy': 99.94481205940247,
#    'sad': 3.171182649808202e-07,
#    'surprise': 3.471185650028019e-06,
#    'neutral': 0.05518436664715409},
#   'dominant_emotion': 'happy',
#   'region': {'x': 877,
#    'y': 412,
#    'w': 910,
#    'h': 910,
#    'left_eye': (1456, 760),
#    'right_eye': (1135, 773)},
#   'face_confidence': 0.92,
#   'age': 21,
#   'gender': {'Woman': 99.79761242866516, 'Man': 0.20239315927028656},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 6.913310289382935,
#    'indian': 1.707489974796772,
#    'black': 0.3212887328118086,
#    'white': 47.22283184528351,
#    'middle eastern': 11.202698200941086,
#    'latino hispanic': 32.632383704185486},
#   'dominant_race': 'white'}]

# %%
prediction=pred[0]
prediction["dominant_emotion"]
# Out:
# 'happy'
